# %% [markdown]
# # <font color=GREEN> HR ANALYTICS </font>

# %% [markdown]
# <font color=BLACK>
# Business Objective:
# </font>
# <font color=ORANGE>
# There is an ever-increasing focus on effective recruitment.
# An organization invests a lot of its time and resources in search of the potential candidates.
# The investment become loses if the selected candidates do not join the organization in the end.
# </font>

# %% [markdown]
# <font color=BLACK>
# Acceptance criteria:
# </font>
# <font color=ORANGE>
# Here we need to analyse whether the potential candidates will join with the organization or not?
# </font>

# %%
# Importing packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(r'D:\Documents\ExcelR_Project\final_new.csv')

# %%
data
# Out:
#         Id    Age  Gender Marital_status Numofcomp_worked Work_Experience  \
# 0        1  19-26    Male         Single             3-5'               5
# 1        2  27-33  Female        Married             0-2'               5
# 2        3  27-33    Male        Married             0-2'               8
# 3        4  19-26    Male         Single             0-2'               8
# 4        5  34-40    Male         Single             6-8'               8
# ...    ...    ...     ...            ...              ...             ...
# 5033  5034  27-33  Female        Married             3-5'               8
# 5034  5035  27-33  Female        Married             0-2'               5
# 5035  5036  27-33  Female         Single          9 Above               8
# 5036  5037  27-33    Male         Single          9 Above               5
# 5037  5038  19-26  Female        Married             0-2'               8
#
#      Last_salary Salary_hike      Work_hours Traveling_required  ...  \
# ...

# %%
data.head()
# Out:
#    Id    Age  Gender Marital_status Numofcomp_worked Work_Experience  \
# 0   1  19-26    Male         Single             3-5'               5
# 1   2  27-33  Female        Married             0-2'               5
# 2   3  27-33    Male        Married             0-2'               8
# 3   4  19-26    Male         Single             0-2'               8
# 4   5  34-40    Male         Single             6-8'               8
#
#   Last_salary Salary_hike Work_hours Traveling_required  ...  \
# 0       7-10K  Above 100%    Mon-Fri                 No  ...
# 1      3.5-7K      50-75%    Mon-Fri                 No  ...
# 2      3.5-7K      25-50%    Mon-Fri                Yes  ...
# 3      3.5-7K      25-50%    Mon-Fri                Yes  ...
# 4      3.5-7K     75-100%    Mon-Fri                 No  ...
#
#         Annual_leave Medical_Family Child_day_care Nursing_room Parking  \
# 0  More Than 12 Days             No             No           No      No
# ...

# %%
data.tail()
# Out:
#         Id    Age  Gender Marital_status Numofcomp_worked Work_Experience  \
# 5033  5034  27-33  Female        Married             3-5'               8
# 5034  5035  27-33  Female        Married             0-2'               5
# 5035  5036  27-33  Female         Single          9 Above               8
# 5036  5037  27-33    Male         Single          9 Above               5
# 5037  5038  19-26  Female        Married             0-2'               8
#
#      Last_salary Salary_hike      Work_hours Traveling_required  ...  \
# 5033       7-10K      50-75%  24/7 Operation                Yes  ...
# 5034      3.5-7K      25-50%         Mon-Fri                 No  ...
# 5035      10-15K     75-100%  Flexible Hours                Yes  ...
# 5036      3.5-7K      25-50%         Mon-Fri                Yes  ...
# 5037      3.5-7K      50-75%         Mon-Fri                 No  ...
#
#            Annual_leave Medical_Family Child_day_care Nursing_room Parking  \
# ...

# %%
data.shape
# Out:
# (5038, 34)

# %%
data.dtypes
# Out:
# Id                                int64
# Age                              object
# Gender                           object
# Marital_status                   object
# Numofcomp_worked                 object
# Work_Experience                  object
# Last_salary                      object
# Salary_hike                      object
# Work_hours                       object
# Traveling_required               object
# NoticePeriod_buyout              object
# Job_type                         object
# Whether_comp_Possess_vehicle     object
# Work_location                    object
# Traveltowork_distance_time       object
# Work_area_living_cost            object
# Public_transport_nearby          object
# Current_employment               object
# Offer_letter_Processtime_week     int64
# Bonus                            object
# Allowance                        object
# Overtime_pay                     object
# Emp_shares_scheme                object
# ...

# %%
data.describe()
# Out:
#                 Id  Offer_letter_Processtime_week
# count  5038.000000                    5038.000000
# mean   2519.500000                       3.207821
# std    1454.489658                       0.899497
# min       1.000000                       1.000000
# 25%    1260.250000                       3.000000
# 50%    2519.500000                       3.000000
# 75%    3778.750000                       4.000000
# max    5038.000000                       5.000000

# %%
data.columns
# Out:
# Index(['Id', 'Age', 'Gender', 'Marital_status', 'Numofcomp_worked',
#        'Work_Experience', 'Last_salary', 'Salary_hike', 'Work_hours',
#        'Traveling_required', 'NoticePeriod_buyout', 'Job_type',
#        'Whether_comp_Possess_vehicle', 'Work_location',
#        'Traveltowork_distance_time', 'Work_area_living_cost',
#        'Public_transport_nearby', 'Current_employment',
#        'Offer_letter_Processtime_week', 'Bonus', 'Allowance', 'Overtime_pay',
#        'Emp_shares_scheme', 'Performance_incentive', 'Annual_leave',
#        'Medical_Family', 'Child_day_care', 'Nursing_room', 'Parking',
#        'Comp_size', 'Comp_rating', 'Work_life', 'Stresslevel', 'Accept_offer'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Id                               5038
# Age                                 4
# Gender                              2
# Marital_status                      2
# Numofcomp_worked                    4
# Work_Experience                     4
# Last_salary                         4
# Salary_hike                         5
# Work_hours                          3
# Traveling_required                  2
# NoticePeriod_buyout                 2
# Job_type                            2
# Whether_comp_Possess_vehicle        2
# Work_location                       3
# Traveltowork_distance_time          3
# Work_area_living_cost               3
# Public_transport_nearby             2
# Current_employment                  2
# Offer_letter_Processtime_week       5
# Bonus                               2
# Allowance                           2
# Overtime_pay                        2
# Emp_shares_scheme                   2
# Performance_incentive               2
# Annual_leave                        2
# ...

# %%
data['Work_location'].unique()
# Out:
# array(['Town', 'Outskirt Town', 'Business Centre'], dtype=object)

# %%
data['Nursing_room'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.isnull()
# Out:
#          Id    Age  Gender  Marital_status  Numofcomp_worked  Work_Experience  \
# 0     False  False   False           False             False            False
# 1     False  False   False           False             False            False
# 2     False  False   False           False             False            False
# 3     False  False   False           False             False            False
# 4     False  False   False           False             False            False
# ...     ...    ...     ...             ...               ...              ...
# 5033  False  False   False           False             False            False
# 5034  False  False   False           False             False            False
# 5035  False  False   False           False             False            False
# 5036  False  False   False           False             False            False
# 5037  False  False   False           False             False            False
#
# ...

# %%
data.isnull().sum()
# Out:
# Id                               0
# Age                              0
# Gender                           0
# Marital_status                   0
# Numofcomp_worked                 0
# Work_Experience                  0
# Last_salary                      0
# Salary_hike                      0
# Work_hours                       0
# Traveling_required               0
# NoticePeriod_buyout              0
# Job_type                         0
# Whether_comp_Possess_vehicle     0
# Work_location                    0
# Traveltowork_distance_time       0
# Work_area_living_cost            0
# Public_transport_nearby          0
# Current_employment               0
# Offer_letter_Processtime_week    0
# Bonus                            0
# Allowance                        0
# Overtime_pay                     0
# Emp_shares_scheme                0
# Performance_incentive            0
# Annual_leave                     0
# Medical_Family                   0
# Child_day_care                   0
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5038 entries, 0 to 5037
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Id                             5038 non-null   int64
#  1   Age                            5038 non-null   object
#  2   Gender                         5038 non-null   object
#  3   Marital_status                 5038 non-null   object
#  4   Numofcomp_worked               5038 non-null   object
#  5   Work_Experience                5038 non-null   object
#  6   Last_salary                    5038 non-null   object
#  7   Salary_hike                    5038 non-null   object
#  8   Work_hours                     5038 non-null   object
#  9   Traveling_required             5038 non-null   object
#  10  NoticePeriod_buyout            5038 non-null   object
#  11  Job_type                       5038 non-null   object
# ...

# %%
# .copy() is used here so that any changes made in new DataFrame don't get reflected in the original one
data1=data.copy()
type
# Out:
# type

# %%
data = data.drop(['Parking', 'Nursing_room', 'Child_day_care'], axis=1)

# %%
data.head()
# Out:
#    Id    Age  Gender Marital_status Numofcomp_worked Work_Experience  \
# 0   1  19-26    Male         Single             3-5'               5
# 1   2  27-33  Female        Married             0-2'               5
# 2   3  27-33    Male        Married             0-2'               8
# 3   4  19-26    Male         Single             0-2'               8
# 4   5  34-40    Male         Single             6-8'               8
#
#   Last_salary Salary_hike Work_hours Traveling_required  ... Overtime_pay  \
# 0       7-10K  Above 100%    Mon-Fri                 No  ...          Yes
# 1      3.5-7K      50-75%    Mon-Fri                 No  ...           No
# 2      3.5-7K      25-50%    Mon-Fri                Yes  ...           No
# 3      3.5-7K      25-50%    Mon-Fri                Yes  ...           No
# 4      3.5-7K     75-100%    Mon-Fri                 No  ...           No
#
#   Emp_shares_scheme Performance_incentive       Annual_leave Medical_Family  \
# ...

# %%
data1.head()
# Out:
#    Id    Age  Gender Marital_status Numofcomp_worked Work_Experience  \
# 0   1  19-26    Male         Single             3-5'               5
# 1   2  27-33  Female        Married             0-2'               5
# 2   3  27-33    Male        Married             0-2'               8
# 3   4  19-26    Male         Single             0-2'               8
# 4   5  34-40    Male         Single             6-8'               8
#
#   Last_salary Salary_hike Work_hours Traveling_required  ...  \
# 0       7-10K  Above 100%    Mon-Fri                 No  ...
# 1      3.5-7K      50-75%    Mon-Fri                 No  ...
# 2      3.5-7K      25-50%    Mon-Fri                Yes  ...
# 3      3.5-7K      25-50%    Mon-Fri                Yes  ...
# 4      3.5-7K     75-100%    Mon-Fri                 No  ...
#
#         Annual_leave Medical_Family Child_day_care Nursing_room Parking  \
# 0  More Than 12 Days             No             No           No      No
# ...

# %%
# Finding Duplicates
data[data.duplicated()].shape
# Out:
# (0, 31)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Age, Gender, Marital_status, Numofcomp_worked, Work_Experience, Last_salary, Salary_hike, Work_hours, Traveling_required, NoticePeriod_buyout, Job_type, Whether_comp_Possess_vehicle, Work_location, Traveltowork_distance_time, Work_area_living_cost, Public_transport_nearby, Current_employment, Offer_letter_Processtime_week, Bonus, Allowance, Overtime_pay, Emp_shares_scheme, Performance_incentive, Annual_leave, Medical_Family, Comp_size, Comp_rating, Work_life, Stresslevel, Accept_offer]
# Index: []
#
# [0 rows x 31 columns]

# %%
data_clean1=data.drop_duplicates()

# %%
data_clean1.shape
# Out:
# (5038, 31)

# %%
corelation = data.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.countplot(x="Age", data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# Conclusion: From above chart we can see that company has more candidates from 19-26 & 27-33 age group.

# %%
sns.countplot(x="Gender", data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Conclusion: From above chart we can see that company has more female candidates than male.

# %%
sns.scatterplot(data['Age'], data['Offer_letter_Processtime_week'], hue=data['Salary_hike'], palette='Set2')
# Out:
# C:\Users\Prathamesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Offer_letter_Processtime_week'>

# %%
sns.countplot(x = 'Age', hue = 'Salary_hike', data = data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Salary_hike", data=data)
# Out:
# <AxesSubplot:xlabel='Salary_hike', ylabel='count'>

# %% [markdown]
# Conclusion: From above 3 charts we can conclude that,
# 1. Some of the candidates from age group 19-26 & 27-33 are getting above 100% salary hike. So, there are more chances that they will accept the offer letter.
# 2. All of the candidates from age group 40 above are getting 50-75% salary hike. So, this age group will definitely join the organization.

# %%
plt.hist(data.Accept_offer,bins=5, rwidth=0.8)
plt.xlabel('How Many Will Accept The Offer')
plt.ylabel('Count')
plt.show()

# %%
data.Accept_offer.describe()
# Out:
# count     5038
# unique       2
# top         No
# freq      2654
# Name: Accept_offer, dtype: object

# %%
sns.countplot(x="Age", hue='Accept_offer', data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# Conclusion: From above 2 observations we can say that,
# 1. More than 50% candidates will not accept the offer.
# 2. More than 50% candidates from age group 19-26 will accept the offer.
# 3. More than 50% candidates from age group 27-33 will not accept the offer.
# 4. From age group 40 above, 100% candidates will accept the offer but their count is very less nearly 100

# %%
sns.countplot(x="Gender", hue='Accept_offer', data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Conclusion: Count of female candidates is greater than male candidates but still more male candidates will aceept the offer than female candidates.

# %%
sns.countplot(x="Gender", hue='Traveltowork_distance_time', data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Conclusion: One of the reason why female candidates are not accepting the offer letter is may be bacause of distance between home to office.

# %%
sns.countplot(x="Marital_status", data=data)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(x="Marital_status", hue='Accept_offer', data=data)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(x="Marital_status", hue='Work_area_living_cost', data=data)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(x="Accept_offer", hue='Work_area_living_cost', data=data)
# Out:
# <AxesSubplot:xlabel='Accept_offer', ylabel='count'>

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=data, kind="line",
    x="Work_area_living_cost", y = "Marital_status", col= "Accept_offer", hue="Age", style="Age")

# %%
sns.relplot ("Work_area_living_cost", "Marital_status", "Accept_offer", data=data, kind="line", hue="Age", style="Age", ci=None)
# Out:
# C:\Users\Prathamesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot ("Work_area_living_cost", "Marital_status", "Accept_offer", data=data, kind="line", 
             hue="Accept_offer", style="Accept_offer", estimator=None)
# Out:
# C:\Users\Prathamesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot ("Work_area_living_cost", "Marital_status", data=data, kind="line", 
             col="Accept_offer", estimator=None)
# Out:
# C:\Users\Prathamesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Conclusion: From above few visualizations we can see that single candidates are more likely to accept the offer than married candidates. This may be because of following reasons:
# 1. Count of single candidates is more than married candidates.
# 2. Or may be because of work area living cost.

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=data, kind="line",
    x="Age", y="Offer_letter_Processtime_week")

# %% [markdown]
# Conclusion: From above chart we can see that offer letter process time is less for the age group of 19-26 & 27-33.

# %%
sns.relplot ("Accept_offer", "Work_hours", data=data, kind="line", 
             col="Bonus", hue="Age", style="Age", estimator=None)
# Out:
# C:\Users\Prathamesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=data, kind="line",
    x="Age", y="Bonus")

# %% [markdown]
# Conclusion: Bonus is mostly applicable to the age group of 19-26 & 27-33.

# %%
sns.countplot(x="Age", hue='Current_employment', data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.displot(data=data, x="Offer_letter_Processtime_week", hue="Age", kind="kde")

# %%
sns.displot(data=data, x="Offer_letter_Processtime_week", hue="Current_employment", kind="kde")

# %% [markdown]
# Conclusion: From above 3 charts we can see that most of the unemployed/resigned candidates are from age group 19-26 and 27-33 and their offer letter process time is also less. So, most probably these candidates will join the company.

# %%
sns.countplot(x="Job_type", hue='Accept_offer', data=data)
# Out:
# <AxesSubplot:xlabel='Job_type', ylabel='count'>

# %% [markdown]
# Conclusion: There are very less chances of candidates with contractual job type will accept the offer. So, we have to concentrate more on permanant job type candidates.

# %%
sns.displot(data=data, x="Id", hue="Work_hours", col="Age", kind="kde")

# %% [markdown]
# Conclusion: Age group of 19-26 & 27-33 are ready to work in flexible hours and 24/7. So, these groups can be considered as good             candidates for company.

# %% [markdown]
# <Font color = Red>
#
# Overall Conclusion:
#
# 1. More candidates have applied from the age group of 19-26 & 27-33. Also the count of female candidates is more than male        candidates but still more male candidates will aceept the offer than female candidates. One of the reason why female            candidates are not accepting the offer letter is may be bacause of distance between home to office is more.
#
# 2. Some of the candidates from age group 19-26 & 27-33 are getting above 100% salary hike. So, there are more chances
#    that they will accept the offer letter.
#
# 3. But more candidates from age group 27-33 are getting low salary hike i.e. between below 25% to 50% and most of the              candidates from age group 19-26 are getting more salary hike i.e. between 50% to 100%.
#
# 4. All of the candidates from age group 40 above are getting 50-75% salary hike. So, this age group will definitely join the      organization.
#
# 5. single candidates are more likely to accept the offer than married candidates. This may be because of following reasons:
#    I.  Count of single candidates is more than married candidates.
#    II. Or may be because of work area living cost.
#
# 6. Also offer letter process time is less for the age group of 19-26 & 27-33.
#
# 7. Bonus is mostly applicable to the age group of 19-26 & 27-33.
#
# 8. If the offer letter process time is within 3 weeks then there are more chances that candidates will accept the offer. Most      of the unemployed/resigned candidates are from age group 19-26 and 27-33. Also their offer letter process time is less.        So, most probably these candidates will join with the organization.
#
# 9. There are very less chances of candidates with contractual job type will accept the offer. So, we have to concentrate more      on permanant job type candidates.
#
# 10. Age group of 19-26 & 27-33 are ready to work in flexible hours and 24/7. So, these groups can be considered as good             candidates for company.
#
#
# </font>

# %% [markdown]
# <Font color = Blue>
#
# Final Conclusion:
#
# We have to concentrate more on 19-26 age group and 40 above age group. Because candidates from this age group has more chances to join the organization.
# And then we can concentrate on 27-33 age group. Because there are less chances that candidates from this age group will accept the offer.
#
# </font>
